# %% [markdown]
# # Data exploration and assessment - federation data
#
# ## Exploring the federation data set

# %%
url = "https://www.powerliftingwatch.com/compare-federations"

# %%
import pandas as pd
import numpy as np

# %%
# Use pandas read_html to scrape data from html tables
dfs = pd.read_html(url)

# %%
type(dfs)
# Out:
# list

# %%
# returns a list of dfs one for each html table

dfs[0][0:10]
# Out:
#             0         1             2             3              4  \
# 0  Federation  Division  Bench Shirts  Bench Shirts  Lifting Suits
# 1         NaN       NaN         Plies      Material          Plies
# 2    100% Raw       NaN             0             -              0
# 3         AAU       Raw             0             -              0
# 4         NaN     Equip             1           Pol              1
# 5        ADAU       NaN             0             -              0
# 6       ADFPF       Raw          0(w)             -              0
# 7         NaN     Equip             1           Pol              1
# 8        AFPF       NaN           UNL   Pol,Den,Can            UNL
# 9         NaN     AAFPF           UNL   Pol,Den,Can            UNL
#
#                5              6     7     8
# 0  Lifting Suits  Lifting Suits  Mono  Test
# 1       Material          Brief   NaN   NaN
# 2              -             No    No   Yes
# 3              -             No    No   Yes
# 4            Pol             No    No   Yes
# 5              -             No    No   Yes
# 6              -             No    No   Yes
# 7            Pol             No    No   Yes
# 8    Pol,Den,Can            Yes   Yes    No
# 9    Pol,Den,Can            Yes   Yes   Yes

# %%
dfs[1][0:10]
# Out:
#             0         1             2             3                    4  \
# 0  Federation  Division  Bench Shirts  Bench Shirts  Lifting/Squat Suits
# 1         NaN       NaN         Plies      Material                Plies
# 2         GPA       NaN          0(w)             -                 0(k)
# 3         GPC  Equipped             2       Pol,Den                  UNL
# 4         NaN       Raw          0(w)             -                 0(k)
# 5         GPF  Equipped             2           NaN                  NaN
# 6         NaN       Raw          0(w)             -                 0(k)
# 7         IPF       NaN             1           Pol                    1
# 8       WDFPF     Equip             1           Pol                    1
# 9         NaN       Raw         0 (w)             -                    0
#
#                      5                    6     7     8
# 0  Lifting/Squat Suits  Lifting/Squat Suits  Mono  Test
# 1             Material               Briefs   NaN   NaN
# 2                    -                    -   Yes    No
# 3          Pol,Den,Can                  Yes   Yes    No
# 4                    -                    -   Yes    No
# 5                  NaN                  NaN   NaN   NaN
# 6                    -                    -   Yes    No
# 7                  Pol                   No    No   Yes
# 8                  Pol                   No    No   Yes
# 9                    -                   No    No   Yes
